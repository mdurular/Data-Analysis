# %%
# Basic Libraries
import pandas as pd
import numpy as np
import scipy
# Libraries for visualizaton
import matplotlib.pyplot as plt
import seaborn as sns
#%matplotlib notebook

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
langs=["C","C++","Java","Python","PHP"]
students=[23,17,35,29,12]
fig,ax=plt.subplots()
ax.bar(langs,students)
for i in range(len(langs)):
    plt.text(langs[i],students[i],str(students[i]),ha="center",va="bottom")

# %%
tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x= "total_bill", y ="tip", data=tips);

# %%
plt.figure(figsize=(12,8))

ax = sns.scatterplot(x='total_bill',y='tip',data=tips)
ax.set(xlabel='Total Bill', ylabel='Tip', title='Some title')

#plt.legend(labels=['legend1'])

plt.show()

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips, hue ="sex", style ="sex");
#hue=groupby

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips, hue ="sex", style ="sex", s=200);
#hue=groupby

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips, size="sex");
#hue=groupby

# %%
sns.scatterplot(x='total_bill',y='tip',s=200, data=tips, alpha=1);
#sns.scatterplot(x='salary',y='sales',data=df,s=200,linewidth=0,alpha=0.2)

# %%
plt.figure(figsize=(12,8))
sns.scatterplot(x='total_bill',y='tip', data=tips,style='sex',hue='sex',s=100)
# Call savefig in the same cell
plt.savefig('example_scatter.jpg')

# %%
sns.rugplot(tips["total_bill"], data =tips)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.rugplot(tips["total_bill"], data =tips, height=0.5)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.displot(x="total_bill", data=tips);

# %%
sns.displot(tips["total_bill"]);

# %%
sns.displot(x="total_bill", data=tips, kde=True);

# %%
sns.histplot(data = tips, x = 'total_bill', kde=True, bins=10 );

# %%
sns.set(style='whitegrid')
sns.histplot(data = tips, x = 'total_bill',bins=20);

# %%
sns.displot(data = tips, x = 'total_bill',bins=20,kde=False,
            color='red',edgecolor='black',lw=4,ls='--')

# %%
sns.kdeplot(data = tips, x = 'total_bill')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data = tips, x = 'total_bill', clip = [10,20])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
sns.kdeplot(data = tips, x = 'total_bill', bw_adjust=0.1);

# %%
sns.kdeplot(data = tips, x = 'total_bill', bw_adjust=0.2, shade=True, color = "r");

# %%
data = pd.DataFrame(np.random.normal(0,1,size=(100,2)),columns=['x','y'])
data
# Out:
#            x         y
# 0   0.575004 -0.118743
# 1  -1.271918  0.309126
# 2   0.901972  0.984513
# 3   2.205618  0.210647
# 4   0.398174  0.081767
# ..       ...       ...
# 95 -0.366915  1.130978
# 96 -0.316020 -1.299013
# 97 -1.150312 -0.784696
# 98 -0.228975 -1.063530
# 99  0.208110 -0.110868
#
# [100 rows x 2 columns]

# %%
sns.kdeplot(data=data , x= "x", y="y")
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %%
sns.kdeplot(data=data , x= "x", y="y", shade=True, cbar=True);

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
sns.kdeplot(data=data , x= "x", y="y")
plt.subplot(1,2,2)
sns.kdeplot(data=data , x= "x", y="y", shade=True);
