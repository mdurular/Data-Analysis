# %% [markdown]
# # PART- 3 ( Handling Outliers )

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
from scipy import stats
from scipy.stats.mstats import winsorize

import warnings
warnings.filterwarnings('ignore')
warnings.warn("this will not show")

# %matplotlib inline
#%matplotlib notebook

plt.rcParams["figure.figsize"] = (10,6)
# plt.rcParams['figure.dpi'] = 100pd.set_option('display.max_columns', 500)

sns.set_style("whitegrid")
pd.set_option('display.float_format', lambda x: '%.3f' % x)

pd.options.display.max_rows = 150
pd.options.display.max_columns = 100

# %%
df = pd.read_csv("filled_scout.csv")

# %% [markdown]
# ## functions to fill the missing values

# %%
def fill_most(df, group_col, col_name):
    '''Fills the missing values with the most existing value (mode) in the relevant column according to single-stage grouping'''
    for group in list(df[group_col].unique()):
        cond = df[group_col]==group
        mode = list(df[cond][col_name].mode())
        if mode != []:
            df.loc[cond, col_name] = df.loc[cond, col_name].fillna(df[cond][col_name].mode()[0])
        else:
            df.loc[cond, col_name] = df.loc[cond, col_name].fillna(df[col_name].mode()[0])
    print("Number of NaN : ",df[col_name].isnull().sum())
    print("------------------")
    print(df[col_name].value_counts(dropna=False))

# %%
def fill_prop(df, group_col, col_name):
    for group in list(df[group_col].unique()):
        cond = df[group_col]==group
        df.loc[cond, col_name] = df.loc[cond, col_name].fillna(method="ffill").fillna(method="bfill")
    df[col_name] = df[col_name].fillna(method="ffill").fillna(method="bfill")
    print("Number of NaN : ",df[col_name].isnull().sum())
    print("------------------")
    print(df[col_name].value_counts(dropna=False))

# %%
def fill(df, group_col1, group_col2, col_name, method): # method can be "mode" or "median" or "ffill"
    if method == "mode":
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond1 = df[group_col1]==group1
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                mode1 = list(df[cond1][col_name].mode())
                mode2 = list(df[cond2][col_name].mode())
                if mode2 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond2][col_name].mode()[0])
                elif mode1 != []:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond1][col_name].mode()[0])
                else:
                    df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[col_name].mode()[0])
                
    elif method == "median":
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond1 = df[group_col1]==group1
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(df[cond2][col_name].median()).fillna(df[cond1][col_name].median()).fillna(df[col_name].median())
                
    elif method == "ffill":           
        for group1 in list(df[group_col1].unique()):
            for group2 in list(df[group_col2].unique()):
                cond2 = (df[group_col1]==group1) & (df[group_col2]==group2)
                df.loc[cond2, col_name] = df.loc[cond2, col_name].fillna(method="ffill").fillna(method="bfill")
                
        for group1 in list(df[group_col1].unique()):
            cond1 = df[group_col1]==group1
            df.loc[cond1, col_name] = df.loc[cond1, col_name].fillna(method="ffill").fillna(method="bfill")            
           
        df[col_name] = df[col_name].fillna(method="ffill").fillna(method="bfill")
    
    print("Number of NaN : ",df[col_name].isnull().sum())
    print("------------------")
    print(df[col_name].value_counts(dropna=False))

# %%
df.shape
# Out:
# (15919, 25)

# %%
df.head(3).T
# Out:
#                                                                      0  \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            15770
# vat                                                     VAT deductible
# km                                                           56013.000
# hp                                                              66.000
# type                                                              Used
# fuel                                                            Diesel
# comfort_convenience  Air conditioning,Armrest,Automatic climate con...
# entertainment_media  Bluetooth,Hands-free equipment,On-board comput...
# extras                  Alloy wheels,Catalytic Converter,Voice Control
# safety_security      ABS,Central door lock,Daytime running lights,D...
# gears                                                            7.000
# age                                                              3.000
# previous_owners                                                  2.000
# inspection_new                                                       1
# paint_type                                                    Metallic
# upholstery_type                                                  Cloth
# nr_of_doors                                                      5.000
# nr_of_seats                                                      5.000
# gear_type                                                    Automatic
# displacement_cc                                               1422.000
# weight_kg                                                     1220.000
# drive_chain                                                      front
# cons_comb                                                        3.800
#
#                                                                      1  \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            14500
# vat                                                   Price negotiable
# km                                                           80000.000
# hp                                                             141.000
# type                                                              Used
# fuel                                                           Benzine
# comfort_convenience  Air conditioning,Automatic climate control,Hil...
# entertainment_media  Bluetooth,Hands-free equipment,On-board comput...
# extras               Alloy wheels,Sport seats,Sport suspension,Voic...
# safety_security      ABS,Central door lock,Central door lock with r...
# gears                                                            7.000
# age                                                              2.000
# previous_owners                                                  2.000
# inspection_new                                                       0
# paint_type                                                    Metallic
# upholstery_type                                                  Cloth
# nr_of_doors                                                      3.000
# nr_of_seats                                                      4.000
# gear_type                                                    Automatic
# displacement_cc                                               1798.000
# weight_kg                                                     1255.000
# drive_chain                                                      front
# cons_comb                                                        5.600
#
#                                                                      2
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            14640
# vat                                                     VAT deductible
# km                                                           83450.000
# hp                                                              85.000
# type                                                              Used
# fuel                                                            Diesel
# comfort_convenience  Air conditioning,Cruise control,Electrical sid...
# entertainment_media                              MP3,On-board computer
# extras                                      Alloy wheels,Voice Control
# safety_security      ABS,Central door lock,Daytime running lights,D...
# gears                                                            7.000
# age                                                              3.000
# previous_owners                                                  1.000
# inspection_new                                                       0
# paint_type                                                    Metallic
# upholstery_type                                                  Cloth
# nr_of_doors                                                      4.000
# nr_of_seats                                                      4.000
# gear_type                                                    Automatic
# displacement_cc                                               1598.000
# weight_kg                                                     1135.000
# drive_chain                                                      front
# cons_comb                                                        3.800

# %% [markdown]
# ## km

# %%
plt.figure(figsize=(15,10))
plt.subplot(141)
plt.hist(df.km, bins = 50)

plt.subplot(142)
plt.boxplot(df.km)

plt.subplot(143)
plt.boxplot(df.km, whis = 2.5)

plt.subplot(144)
plt.boxplot(np.log(df.km), whis = 2.5)
plt.show()

# %% [markdown]
# km is a variable with a wide range of values. We can not consider the outlier values above as a real outliers. So let's keep it as it is.

# %% [markdown]
# ## cons_comb

# %%
df.cons_comb.describe()
# Out:
# count   15919.000
# mean        4.832
# std         0.868
# min         3.000
# 25%         4.100
# 50%         4.800
# 75%         5.400
# max         9.100
# Name: cons_comb, dtype: float64

# %%
df.cons_comb.sort_values().head(10)
# Out:
# 6440    3.000
# 2863    3.000
# 2862    3.000
# 13493   3.000
# 13482   3.000
# 11004   3.000
# 11015   3.000
# 11044   3.000
# 811     3.000
# 6240    3.000
# Name: cons_comb, dtype: float64

# %%
df.cons_comb.sort_values().tail(10)
# Out:
# 3601    8.300
# 3649    8.300
# 10789   8.600
# 12553   8.600
# 12530   8.600
# 12422   8.600
# 10817   8.700
# 12054   8.700
# 12529   8.700
# 10771   9.100
# Name: cons_comb, dtype: float64

# %% [markdown]
# Using our domain knowledge we can conclude that min value of 3 and max value of 9.10 are normal. But anyways, let's analyze outliers with plotting, np.log and winsorize methods.

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
plt.hist(df.cons_comb, bins = 25)

plt.subplot(122)
plt.boxplot(df.cons_comb, whis = 2.5)

plt.show()

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
plt.hist(np.log(df.cons_comb), bins = 25)

plt.subplot(122)
plt.boxplot(np.log(df.cons_comb), whis = 2)

plt.show()

# %%
plt.figure(figsize = (10, 6))
plt.subplot(121)
plt.hist(winsorize(df.cons_comb, (0.003)), bins = 22)
# Winsorizing or winsorization is the transformation of statistics by limiting extreme values in the statistical data to reduce the effect of possibly spurious outliers. 

plt.subplot(122)
plt.boxplot(winsorize(df.cons_comb, (0.003)), whis = 2)

plt.show()

# %% [markdown]
# ## displacement_cc

# %%
df.displacement_cc.describe()
# Out:
# count   15919.000
# mean     1425.609
# std       329.720
# min         1.000
# 25%      1229.000
# 50%      1461.000
# 75%      1598.000
# max     16000.000
# Name: displacement_cc, dtype: float64

# %%
df.sort_values(by = ["displacement_cc"], ascending = False)["displacement_cc"].head(55)
# Out:
# 10932   16000.000
# 7169    15898.000
# 10771    2967.000
# 3595     2480.000
# 3587     2480.000
# 3649     2480.000
# 3590     2480.000
# 3599     2480.000
# 3598     2480.000
# 3596     2480.000
# 3600     2480.000
# 3601     2480.000
# 3610     2480.000
# 3609     2480.000
# 3608     2480.000
# 3606     2480.000
# 3605     2480.000
# 3648     2480.000
# 3592     2480.000
# 3593     2480.000
# 3602     2480.000
# 3604     2480.000
# 3603     2480.000
# 12176    2000.000
# 12462    2000.000
# 12521    2000.000
# 12170    2000.000
# 13027    2000.000
# 11929    2000.000
# 12179    2000.000
# 11935    2000.000
# 12181    2000.000
# 11800    2000.000
# 4188     2000.000
# 12526    2000.000
# 12959    2000.000
# 12527    2000.000
# 11977    2000.000
# 12469    2000.000
# 12520    2000.000
# 12464    2000.000
# 12265    2000.000
# 11870    2000.000
# 10556    2000.000
# 2903     2000.000
# 15197    2000.000
# 12414    2000.000
# 11988    2000.000
# 13050    2000.000
# 12412    2000.000
# 10464    2000.000
# 12560    2000.000
# 12411    2000.000
# 11032    2000.000
# 13054    2000.000
# Name: displacement_cc, dtype: float64

# %%
df.sort_values(by = ["displacement_cc"], ascending = True)["displacement_cc"].head(55)
# Out:
# 12790     1.000
# 14319     1.000
# 14315     1.000
# 12849     1.000
# 12848     1.000
# 12835     1.000
# 12823     1.000
# 12815     1.000
# 12800     1.000
# 12798     1.000
# 12796     1.000
# 12786     1.000
# 12783     1.000
# 12781     1.000
# 12769     1.000
# 12768     1.000
# 12750     1.000
# 12670     1.000
# 12604     1.000
# 12554     1.000
# 12501     1.000
# 12499     1.000
# 12484     1.000
# 12473     1.000
# 12467     1.000
# 14284     1.000
# 14320     1.000
# 14321     1.000
# 14314     1.000
# 14322     1.000
# 14328     1.000
# 14327     1.000
# 13904     1.000
# 14325     1.000
# 14326     1.000
# 14324     1.000
# 10559     2.000
# 14198     2.000
# 13912    54.000
# 10194   122.000
# 7810    139.000
# 7812    139.000
# 7811    139.000
# 7809    139.000
# 8128    140.000
# 15578   160.000
# 15576   160.000
# 15574   160.000
# 15575   160.000
# 15577   160.000
# 15579   160.000
# 13653   890.000
# 14694   898.000
# 14342   898.000
# 14695   898.000
# Name: displacement_cc, dtype: float64

# %%
outlier_bool_list = df.displacement_cc.isin([1, 2, 54, 122, 139, 140, 160, 16000, 15898])

# %%
outlier_bool_list
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15914    False
# 15915    False
# 15916    False
# 15917    False
# 15918    False
# Name: displacement_cc, Length: 15919, dtype: bool

# %%
df.loc[outlier_bool_list, "displacement_cc"] = np.nan

# %%
fill(df, "make_model", "body_type", "displacement_cc", "mode")
# Out:
# Number of NaN :  0
# ------------------
# 1598.000    5077
# 999.000     2467
# 1398.000    1388
# 1399.000     772
# 1461.000     682
# 1229.000     678
# 1956.000     670
# 1490.000     559
# 1422.000     467
# 1197.000     372
# 898.000      351
# 1395.000     320
# 1968.000     301
# 1149.000     288
# 1618.000     212
# 1798.000     210
# 1498.000     196
# 1600.000     130
# 1248.000     110
# 1997.000     103
# 1364.000     102
# 1400.000      90
# 998.000       72
# 1500.000      50
# 2000.000      46
# 1000.000      40
# 1998.000      25
# 2480.000      20
# 1984.000      18
# 1200.000      18
# 899.000       11
# 1397.000      11
# 1499.000       5
# 929.000        5
# 1596.000       4
# 900.000        4
# 997.000        4
# 1396.000       3
# 1199.000       3
# 1599.000       3
# 1589.000       2
# 995.000        2
# 1300.000       2
# 1495.000       2
# 1390.000       1
# 1696.000       1
# 1568.000       1
# 1368.000       1
# 890.000        1
# 1239.000       1
# 1496.000       1
# 973.000        1
# 996.000        1
# 1198.000       1
# 1333.000       1
# 1584.000       1
# 1686.000       1
# 1856.000       1
# 1369.000       1
# 1995.000       1
# 2967.000       1
# 1896.000       1
# 1100.000       1
# 1195.000       1
# 1800.000       1
# 1350.000       1
# 1580.000       1
# 1533.000       1
# Name: displacement_cc, dtype: int64

# %%
plt.figure(figsize=(10,6))
plt.subplot(121)
plt.hist(df.displacement_cc, bins = 20)

plt.subplot(122)
plt.boxplot(df.displacement_cc, whis = 2.5)

plt.show()

# %% [markdown]
# - There is no problem in terms of outliers

# %% [markdown]
# ## Nr_of_Doors

# %%
df.nr_of_doors.value_counts(dropna = False)
# Out:
# 5.000    11787
# 4.000     3079
# 3.000      832
# 2.000      219
# 7.000        1
# 1.000        1
# Name: nr_of_doors, dtype: int64

# %%
df.nr_of_doors.replace([1, 7], np.nan, inplace=True)

# %%
df.nr_of_doors.value_counts(dropna = False)
# Out:
# 5.000    11787
# 4.000     3079
# 3.000      832
# 2.000      219
# NaN          2
# Name: nr_of_doors, dtype: int64

# %%
fill(df, "make_model", "body_type", "nr_of_doors", "mode")
# Out:
# Number of NaN :  0
# ------------------
# 5.000    11789
# 4.000     3079
# 3.000      832
# 2.000      219
# Name: nr_of_doors, dtype: int64

# %%
df.nr_of_doors.value_counts(dropna = False).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.groupby(["make_model", "nr_of_doors"]).nr_of_doors.count().plot.bar()
# Out:
# <AxesSubplot:xlabel='make_model,nr_of_doors'>

# %%
df.drop("nr_of_doors", axis=1, inplace=True)

# %% [markdown]
# ## Nr_of_Seats

# %%
df.nr_of_seats.value_counts(dropna = False)
# Out:
# 5.000    14308
# 4.000     1127
# 7.000      362
# 2.000      119
# 6.000        2
# 3.000        1
# Name: nr_of_seats, dtype: int64

# %%
df.nr_of_seats.replace([3, 6], np.nan, inplace=True)

# %%
df.nr_of_seats.value_counts(dropna = False)
# Out:
# 5.000    14308
# 4.000     1127
# 7.000      362
# 2.000      119
# NaN          3
# Name: nr_of_seats, dtype: int64

# %%
fill(df, "make_model", "body_type", "nr_of_seats", "mode")
# Out:
# Number of NaN :  0
# ------------------
# 5.000    14311
# 4.000     1127
# 7.000      362
# 2.000      119
# Name: nr_of_seats, dtype: int64

# %%
df.nr_of_seats.value_counts(dropna = False).plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.groupby(["make_model", "nr_of_seats"]).nr_of_seats.count().plot.bar();

# %%
df.drop("nr_of_seats", axis=1, inplace=True)

# %% [markdown]
# ## Weight_kg

# %%
df.weight_kg.describe()
# Out:
# count   15919.000
# mean     1337.432
# std       200.466
# min         1.000
# 25%      1165.000
# 50%      1295.000
# 75%      1472.000
# max      2471.000
# Name: weight_kg, dtype: float64

# %%
df["weight_kg"].sort_values().head(10)
# Out:
# 8355      1.000
# 12779     1.000
# 1143    102.000
# 8857    840.000
# 14313   900.000
# 13513   977.000
# 13555   977.000
# 14654   980.000
# 14105   980.000
# 13999   980.000
# Name: weight_kg, dtype: float64

# %%
df["weight_kg"].sort_values().tail(10)
# Out:
# 10638   2450.000
# 10646   2450.000
# 14975   2471.000
# 15678   2471.000
# 15185   2471.000
# 15231   2471.000
# 15280   2471.000
# 1143         NaN
# 8355         NaN
# 12779        NaN
# Name: weight_kg, dtype: float64

# %%
df["weight_kg"].replace([1, 102], np.nan, inplace = True)

# %%
df["weight_kg"].isnull().sum()
# Out:
# 3

# %%
fill(df, "make_model", "body_type", "weight_kg", "mode")
# Out:
# Number of NaN :  0
# ------------------
# 1163.000    1583
# 1360.000    1419
# 1487.000     967
# 1135.000     837
# 1425.000     744
#             ...
# 1797.000       1
# 1950.000       1
# 900.000        1
# 1272.000       1
# 1159.000       1
# Name: weight_kg, Length: 432, dtype: int64

# %%
plt.figure(figsize=(10,6))

plt.subplot(121)
plt.hist(df.weight_kg, bins=15)

plt.subplot(122)
plt.boxplot(df.weight_kg, whis=2.5)

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.subplot(121)
plt.hist(np.log(df.weight_kg), bins=15)

plt.subplot(122)
plt.boxplot(np.log(df.weight_kg), whis=2.5)

plt.show()

# %% [markdown]
# ## hp

# %%
df.hp.describe()
# Out:
# count   15919.000
# mean       88.374
# std        26.844
# min         1.000
# 25%        66.000
# 50%        85.000
# 75%       101.000
# max       294.000
# Name: hp, dtype: float64

# %%
df.hp.sort_values().head(50)
# Out:
# 6034     1.000
# 6946     1.000
# 7014     1.000
# 9285     1.000
# 9287     1.000
# 6005     1.000
# 9288     1.000
# 7018     1.000
# 9289     1.000
# 9290     1.000
# 9292     1.000
# 9299     1.000
# 10610    1.000
# 10580    1.000
# 10579    1.000
# 10468    1.000
# 15155    1.000
# 15156    1.000
# 7019     1.000
# 7016     1.000
# 13885    4.000
# 3913     9.000
# 8857    40.000
# 13759   40.000
# 8408    44.000
# 10282   51.000
# 10283   51.000
# 10284   51.000
# 10285   51.000
# 10286   51.000
# 10287   51.000
# 9145    51.000
# 10288   51.000
# 10346   51.000
# 10281   51.000
# 10330   51.000
# 9026    51.000
# 9025    51.000
# 10342   51.000
# 10289   51.000
# 9159    51.000
# 9384    51.000
# 9158    51.000
# 10290   51.000
# 10291   51.000
# 10345   51.000
# 10280   51.000
# 10279   51.000
# 10278   51.000
# 10264   51.000
# Name: hp, dtype: float64

# %%
df.hp.unique()
# Out:
# array([ 66., 141.,  85.,  70.,  92., 112.,  60.,  71.,  67., 110.,  93.,
#        147.,  86., 140.,  87.,  81.,  82., 135., 132., 100.,  96., 162.,
#        150., 294., 228., 270., 137.,   9., 133.,  77., 101.,  78., 103.,
#          1.,  74., 118.,  84.,  88.,  80.,  76., 149.,  51.,  44.,  55.,
#         52.,  63.,  40.,  65.,  75., 125., 120., 184., 239., 121., 143.,
#        191.,  89., 195., 127., 122., 154., 155., 104., 123., 146.,  90.,
#         56.,  53.,  54., 164.,   4., 163.,  57., 119., 165., 117., 115.,
#         98., 168., 167.])

# %%
df.hp.loc[df.hp < 40] = np.nan

# %%
df.hp.isnull().sum()
# Out:
# 22

# %%
fill(df, "make_model", "body_type", "hp", "mode")
# Out:
# Number of NaN :  0
# ------------------
# 85.000     2544
# 66.000     2124
# 81.000     1403
# 100.000    1317
# 110.000    1117
# 70.000      890
# 125.000     715
# 51.000      703
# 55.000      589
# 118.000     552
# 92.000      466
# 121.000     392
# 147.000     380
# 77.000      353
# 56.000      295
# 54.000      276
# 103.000     253
# 87.000      232
# 165.000     194
# 88.000      177
# 60.000      160
# 162.000      98
# 74.000       81
# 96.000       72
# 71.000       59
# 101.000      47
# 67.000       40
# 154.000      39
# 122.000      35
# 119.000      30
# 164.000      27
# 135.000      24
# 82.000       22
# 52.000       22
# 78.000       20
# 146.000      18
# 294.000      18
# 141.000      16
# 57.000       10
# 120.000       8
# 104.000       8
# 191.000       7
# 112.000       7
# 155.000       6
# 117.000       6
# 184.000       5
# 90.000        4
# 65.000        4
# 76.000        4
# 98.000        3
# 80.000        3
# 93.000        3
# 149.000       3
# 168.000       3
# 40.000        2
# 86.000        2
# 53.000        2
# 228.000       2
# 167.000       2
# 143.000       2
# 150.000       2
# 63.000        2
# 140.000       2
# 89.000        2
# 127.000       2
# 270.000       2
# 239.000       1
# 44.000        1
# 195.000       1
# 132.000       1
# 133.000       1
# 115.000       1
# 163.000       1
# 84.000        1
# 137.000       1
# 123.000       1
# 75.000        1
# Name: hp, dtype: int64

# %%
plt.figure(figsize=(10,6))

plt.subplot(121)
plt.hist(df.hp, bins=15)

plt.subplot(122)
plt.boxplot(df.hp, whis=2.5)

plt.show()

# %%
plt.figure(figsize=(10,6))

plt.subplot(121)
plt.hist(np.log(df.hp), bins=15)

plt.subplot(122)
plt.boxplot(np.log(df.hp), whis=2.5)

plt.show()

# %% [markdown]
# ## price

# %%
df.price.describe()
# Out:
# count   15919.000
# mean    18019.897
# std      7386.169
# min        13.000
# 25%     12850.000
# 50%     16900.000
# 75%     21900.000
# max     74600.000
# Name: price, dtype: float64

# %%
df.price.sort_values().head(5)
# Out:
# 8594      13
# 8828     120
# 6066     255
# 8829     331
# 8827    4950
# Name: price, dtype: int64

# %%
df.drop(index = [8594, 8828, 6066,8829], axis = 0, inplace = True)

# %%
df.shape
# Out:
# (15915, 23)

# %%
plt.figure(figsize=(10,6))
plt.subplot(121)
plt.hist(df.price, bins=20)

plt.subplot(122)
plt.boxplot(df.price, whis=3)

plt.show()

# %%
plt.figure(figsize=(10,6))
plt.subplot(121)
plt.hist(np.log(df.price), bins=20)

plt.subplot(122)
plt.boxplot(np.log(df.price), whis=2.3)

plt.show()

# %%
plt.figure(figsize=(16,6))
sns.boxplot(x="make_model", y="price", data=df, whis=3)
plt.show()

# %%
plt.figure(figsize=(16,6))
sns.boxplot(x="make_model", y=np.log(df.price), data=df, whis=2.3)
plt.show()

# %% [markdown]
# ## Final_Step

# %%
df.head(3).T
# Out:
#                                                                      0  \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            15770
# vat                                                     VAT deductible
# km                                                           56013.000
# hp                                                              66.000
# type                                                              Used
# fuel                                                            Diesel
# comfort_convenience  Air conditioning,Armrest,Automatic climate con...
# entertainment_media  Bluetooth,Hands-free equipment,On-board comput...
# extras                  Alloy wheels,Catalytic Converter,Voice Control
# safety_security      ABS,Central door lock,Daytime running lights,D...
# gears                                                            7.000
# age                                                              3.000
# previous_owners                                                  2.000
# inspection_new                                                       1
# paint_type                                                    Metallic
# upholstery_type                                                  Cloth
# gear_type                                                    Automatic
# displacement_cc                                               1422.000
# weight_kg                                                     1220.000
# drive_chain                                                      front
# cons_comb                                                        3.800
#
#                                                                      1  \
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            14500
# vat                                                   Price negotiable
# km                                                           80000.000
# hp                                                             141.000
# type                                                              Used
# fuel                                                           Benzine
# comfort_convenience  Air conditioning,Automatic climate control,Hil...
# entertainment_media  Bluetooth,Hands-free equipment,On-board comput...
# extras               Alloy wheels,Sport seats,Sport suspension,Voic...
# safety_security      ABS,Central door lock,Central door lock with r...
# gears                                                            7.000
# age                                                              2.000
# previous_owners                                                  2.000
# inspection_new                                                       0
# paint_type                                                    Metallic
# upholstery_type                                                  Cloth
# gear_type                                                    Automatic
# displacement_cc                                               1798.000
# weight_kg                                                     1255.000
# drive_chain                                                      front
# cons_comb                                                        5.600
#
#                                                                      2
# make_model                                                     Audi A1
# body_type                                                       Sedans
# price                                                            14640
# vat                                                     VAT deductible
# km                                                           83450.000
# hp                                                              85.000
# type                                                              Used
# fuel                                                            Diesel
# comfort_convenience  Air conditioning,Cruise control,Electrical sid...
# entertainment_media                              MP3,On-board computer
# extras                                      Alloy wheels,Voice Control
# safety_security      ABS,Central door lock,Daytime running lights,D...
# gears                                                            7.000
# age                                                              3.000
# previous_owners                                                  1.000
# inspection_new                                                       0
# paint_type                                                    Metallic
# upholstery_type                                                  Cloth
# gear_type                                                    Automatic
# displacement_cc                                               1598.000
# weight_kg                                                     1135.000
# drive_chain                                                      front
# cons_comb                                                        3.800

# %%
numeric_col = "price,km,gears,previous_owners,cons_comb,displacement_cc,age,hp,weight_kg".split(",")

# %%
df_num = df[numeric_col]

# %%
df_num
# Out:
#        price        km  gears  previous_owners  cons_comb  displacement_cc  \
# 0      15770 56013.000  7.000            2.000      3.800         1422.000
# 1      14500 80000.000  7.000            2.000      5.600         1798.000
# 2      14640 83450.000  7.000            1.000      3.800         1598.000
# 3      14500 73000.000  6.000            1.000      3.800         1422.000
# 4      16790 16200.000  7.000            1.000      4.100         1422.000
# ...      ...       ...    ...              ...        ...              ...
# 15914  39950  1647.363  6.000            1.000      5.300         1997.000
# 15915  39885  9900.000  7.000            1.000      7.400         1798.000
# 15916  39875    15.000  6.000            1.000      5.300         1997.000
# 15917  39700    10.000  6.000            1.000      5.300         1997.000
# 15918  40999  1647.363  6.000            1.000      6.800         1798.000
#
#         age      hp  weight_kg
# 0     3.000  66.000   1220.000
# 1     2.000 141.000   1255.000
# 2     3.000  85.000   1135.000
# 3     3.000  66.000   1195.000
# 4     3.000  66.000   1135.000
# ...     ...     ...        ...
# 15914 0.000 147.000   1758.000
# 15915 0.000 165.000   1708.000
# 15916 0.000 146.000   1734.000
# 15917 0.000 147.000   1758.000
# 15918 0.000 165.000   1685.000
#
# [15915 rows x 9 columns]

# %%
plt.figure(figsize = (16,12))
plt.title("Corr HeatMap")
sns.heatmap(df_num.corr(), annot = True, cmap="RdYlGn", linewidths=0.2, annot_kws = {"size": 16});

# %%
sns.pairplot(df_num, size = 2.5)
plt.show()

# %% [markdown]
# ## Dummy Operation

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15915 entries, 0 to 15918
# Data columns (total 23 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   make_model           15915 non-null  object
#  1   body_type            15915 non-null  object
#  2   price                15915 non-null  int64
#  3   vat                  15915 non-null  object
#  4   km                   15915 non-null  float64
#  5   hp                   15915 non-null  float64
#  6   type                 15915 non-null  object
#  7   fuel                 15915 non-null  object
#  8   comfort_convenience  15915 non-null  object
#  9   entertainment_media  15915 non-null  object
#  10  extras               15915 non-null  object
#  11  safety_security      15915 non-null  object
#  12  gears                15915 non-null  float64
#  13  age                  15915 non-null  float64
#  14  previous_owners      15915 non-null  float64
#  15  inspection_new       15915 non-null  int64
#  16  paint_type           15915 non-null  object
#  17  upholstery_type      15915 non-null  object
#  18  gear_type            15915 non-null  object
#  19  displacement_cc      15915 non-null  float64
#  20  weight_kg            15915 non-null  float64
#  21  drive_chain          15915 non-null  object
#  22  cons_comb            15915 non-null  float64
# dtypes: float64(8), int64(2), object(13)
# memory usage: 3.4+ MB

# %%
df.to_csv("final_scout_not_dummy.csv", index=False)

# %%
df[["comfort_convenience", "entertainment_media", "extras", "safety_security"]]
# Out:
#                                      comfort_convenience  \
# 0      Air conditioning,Armrest,Automatic climate con...
# 1      Air conditioning,Automatic climate control,Hil...
# 2      Air conditioning,Cruise control,Electrical sid...
# 3      Air suspension,Armrest,Auxiliary heating,Elect...
# 4      Air conditioning,Armrest,Automatic climate con...
# ...                                                  ...
# 15914  Air conditioning,Automatic climate control,Cru...
# 15915  Air conditioning,Automatic climate control,Cru...
# 15916  Air conditioning,Armrest,Automatic climate con...
# 15917  Air conditioning,Automatic climate control,Cru...
# 15918  Air conditioning,Automatic climate control,Cru...
#
#                                      entertainment_media  \
# 0      Bluetooth,Hands-free equipment,On-board comput...
# 1      Bluetooth,Hands-free equipment,On-board comput...
# 2                                  MP3,On-board computer
# 3      Bluetooth,CD player,Hands-free equipment,MP3,O...
# 4      Bluetooth,CD player,Hands-free equipment,MP3,O...
# ...                                                  ...
# 15914  Bluetooth,Digital radio,Hands-free equipment,O...
# 15915  Bluetooth,Digital radio,Hands-free equipment,R...
# 15916  Bluetooth,Hands-free equipment,On-board comput...
# 15917                  Bluetooth,Digital radio,Radio,USB
# 15918                                                USB
#
#                                                   extras  \
# 0         Alloy wheels,Catalytic Converter,Voice Control
# 1      Alloy wheels,Sport seats,Sport suspension,Voic...
# 2                             Alloy wheels,Voice Control
# 3                 Alloy wheels,Sport seats,Voice Control
# 4      Alloy wheels,Sport package,Sport suspension,Vo...
# ...                                                  ...
# 15914                          Alloy wheels,Touch screen
# 15915            Alloy wheels,Touch screen,Voice Control
# 15916                                       Alloy wheels
# 15917                          Alloy wheels,Touch screen
# 15918                          Alloy wheels,Touch screen
#
#                                          safety_security
# 0      ABS,Central door lock,Daytime running lights,D...
# 1      ABS,Central door lock,Central door lock with r...
# 2      ABS,Central door lock,Daytime running lights,D...
# 3      ABS,Alarm system,Central door lock with remote...
# 4      ABS,Central door lock,Driver-side airbag,Elect...
# ...                                                  ...
# 15914  ABS,Central door lock,Central door lock with r...
# 15915  ABS,Adaptive Cruise Control,Blind spot monitor...
# 15916  ABS,Adaptive Cruise Control,Blind spot monitor...
# 15917  ABS,Blind spot monitor,Driver-side airbag,Elec...
# 15918  ABS,Blind spot monitor,Daytime running lights,...
#
# [15915 rows x 4 columns]

# %%
# STR + GET_DUMMIES

df = df.join(df["comfort_convenience"].str.get_dummies(sep = ",").add_prefix("cc_"))
df = df.join(df["entertainment_media"].str.get_dummies(sep = ",").add_prefix("em_"))
df = df.join(df["extras"].str.get_dummies(sep = ",").add_prefix("ex_"))
df = df.join(df["safety_security"].str.get_dummies(sep = ",").add_prefix("ss_"))

# %%
df.drop(["comfort_convenience", "entertainment_media", "extras", "safety_security"], axis=1, inplace=True)

# %%
df.shape
# Out:
# (15915, 113)

# %%
df.head(2).T
# Out:
#                                                        0                 1
# make_model                                       Audi A1           Audi A1
# body_type                                         Sedans            Sedans
# price                                              15770             14500
# vat                                       VAT deductible  Price negotiable
# km                                             56013.000         80000.000
# hp                                                66.000           141.000
# type                                                Used              Used
# fuel                                              Diesel           Benzine
# gears                                              7.000             7.000
# age                                                3.000             2.000
# previous_owners                                    2.000             2.000
# inspection_new                                         1                 0
# paint_type                                      Metallic          Metallic
# upholstery_type                                    Cloth             Cloth
# gear_type                                      Automatic         Automatic
# displacement_cc                                 1422.000          1798.000
# weight_kg                                       1220.000          1255.000
# drive_chain                                        front             front
# cons_comb                                          3.800             5.600
# cc_Air conditioning                                    1                 1
# cc_Air suspension                                      0                 0
# cc_Armrest                                             1                 0
# cc_Automatic climate control                           1                 1
# cc_Auxiliary heating                                   0                 0
# cc_Cruise control                                      1                 0
# cc_Electric Starter                                    0                 0
# cc_Electric tailgate                                   0                 0
# cc_Electrical side mirrors                             1                 0
# cc_Electrically adjustable seats                       0                 0
# cc_Electrically heated windshield                      0                 0
# cc_Heads-up display                                    0                 0
# cc_Heated steering wheel                               0                 0
# cc_Hill Holder                                         1                 1
# cc_Keyless central door lock                           0                 0
# cc_Leather seats                                       0                 0
# cc_Leather steering wheel                              1                 1
# cc_Light sensor                                        1                 0
# cc_Lumbar support                                      0                 1
# cc_Massage seats                                       0                 0
# cc_Multi-function steering wheel                       1                 0
# cc_Navigation system                                   1                 0
# cc_Panorama roof                                       0                 0
# cc_Park Distance Control                               1                 0
# cc_Parking assist system camera                        0                 0
# cc_Parking assist system self-steering                 0                 0
# cc_Parking assist system sensors front                 0                 0
# cc_Parking assist system sensors rear                  1                 1
# cc_Power windows                                       1                 1
# cc_Rain sensor                                         1                 0
# cc_Seat heating                                        1                 0
# cc_Seat ventilation                                    0                 0
# cc_Split rear seats                                    0                 0
# cc_Start-stop system                                   1                 1
# cc_Sunroof                                             0                 0
# cc_Tinted windows                                      0                 1
# cc_Wind deflector                                      0                 0
# cc_Windshield                                          0                 0
# em_Bluetooth                                           1                 1
# em_CD player                                           0                 0
# em_Digital radio                                       0                 0
# em_Hands-free equipment                                1                 1
# em_MP3                                                 0                 0
# em_On-board computer                                   1                 1
# em_Radio                                               1                 1
# em_Sound system                                        0                 1
# em_Television                                          0                 0
# em_USB                                                 0                 0
# ex_Alloy wheels                                        1                 1
# ex_Cab or rented Car                                   0                 0
# ex_Catalytic Converter                                 1                 0
# ex_Handicapped enabled                                 0                 0
# ex_Right hand drive                                    0                 0
# ex_Roof rack                                           0                 0
# ex_Shift paddles                                       0                 0
# ex_Ski bag                                             0                 0
# ex_Sliding door                                        0                 0
# ex_Sport package                                       0                 0
# ex_Sport seats                                         0                 1
# ex_Sport suspension                                    0                 1
# ex_Touch screen                                        0                 0
# ex_Trailer hitch                                       0                 0
# ex_Tuned car                                           0                 0
# ex_Voice Control                                       1                 1
# ex_Winter tyres                                        0                 0
# ss_ABS                                                 1                 1
# ss_Adaptive Cruise Control                             0                 0
# ss_Adaptive headlights                                 0                 0
# ss_Alarm system                                        0                 0
# ss_Blind spot monitor                                  0                 0
# ss_Central door lock                                   1                 1
# ss_Central door lock with remote control               0                 1
# ss_Daytime running lights                              1                 1
# ss_Driver drowsiness detection                         0                 0
# ss_Driver-side airbag                                  1                 1
# ss_Electronic stability control                        1                 1
# ss_Emergency brake assistant                           0                 0
# ss_Emergency system                                    0                 0
# ss_Fog lights                                          1                 0
# ss_Head airbag                                         0                 1
# ss_Immobilizer                                         1                 1
# ss_Isofix                                              1                 1
# ss_LED Daytime Running Lights                          0                 0
# ss_LED Headlights                                      0                 0
# ss_Lane departure warning system                       0                 0
# ss_Night view assist                                   0                 0
# ss_Passenger-side airbag                               1                 1
# ss_Power steering                                      1                 1
# ss_Rear airbag                                         0                 0
# ss_Side airbag                                         1                 1
# ss_Tire pressure monitoring system                     1                 1
# ss_Traction control                                    1                 1
# ss_Traffic sign recognition                            0                 0
# ss_Xenon headlights                                    1                 1

# %%
df_final = pd.get_dummies(df)

# %%
df_final.shape
# Out:
# (15915, 143)

# %%
df_final.head().T
# Out:
#                                                  0         1         2  \
# price                                    15770.000 14500.000 14640.000
# km                                       56013.000 80000.000 83450.000
# hp                                          66.000   141.000    85.000
# gears                                        7.000     7.000     7.000
# age                                          3.000     2.000     3.000
# previous_owners                              2.000     2.000     1.000
# inspection_new                               1.000     0.000     0.000
# displacement_cc                           1422.000  1798.000  1598.000
# weight_kg                                 1220.000  1255.000  1135.000
# cons_comb                                    3.800     5.600     3.800
# cc_Air conditioning                          1.000     1.000     1.000
# cc_Air suspension                            0.000     0.000     0.000
# cc_Armrest                                   1.000     0.000     0.000
# cc_Automatic climate control                 1.000     1.000     0.000
# cc_Auxiliary heating                         0.000     0.000     0.000
# cc_Cruise control                            1.000     0.000     1.000
# cc_Electric Starter                          0.000     0.000     0.000
# cc_Electric tailgate                         0.000     0.000     0.000
# cc_Electrical side mirrors                   1.000     0.000     1.000
# cc_Electrically adjustable seats             0.000     0.000     0.000
# cc_Electrically heated windshield            0.000     0.000     0.000
# cc_Heads-up display                          0.000     0.000     0.000
# cc_Heated steering wheel                     0.000     0.000     0.000
# cc_Hill Holder                               1.000     1.000     1.000
# cc_Keyless central door lock                 0.000     0.000     0.000
# cc_Leather seats                             0.000     0.000     0.000
# cc_Leather steering wheel                    1.000     1.000     1.000
# cc_Light sensor                              1.000     0.000     0.000
# cc_Lumbar support                            0.000     1.000     0.000
# cc_Massage seats                             0.000     0.000     0.000
# cc_Multi-function steering wheel             1.000     0.000     1.000
# cc_Navigation system                         1.000     0.000     1.000
# cc_Panorama roof                             0.000     0.000     0.000
# cc_Park Distance Control                     1.000     0.000     1.000
# cc_Parking assist system camera              0.000     0.000     0.000
# cc_Parking assist system self-steering       0.000     0.000     0.000
# cc_Parking assist system sensors front       0.000     0.000     1.000
# cc_Parking assist system sensors rear        1.000     1.000     1.000
# cc_Power windows                             1.000     1.000     1.000
# cc_Rain sensor                               1.000     0.000     0.000
# cc_Seat heating                              1.000     0.000     1.000
# cc_Seat ventilation                          0.000     0.000     0.000
# cc_Split rear seats                          0.000     0.000     0.000
# cc_Start-stop system                         1.000     1.000     1.000
# cc_Sunroof                                   0.000     0.000     0.000
# cc_Tinted windows                            0.000     1.000     0.000
# cc_Wind deflector                            0.000     0.000     0.000
# cc_Windshield                                0.000     0.000     0.000
# em_Bluetooth                                 1.000     1.000     0.000
# em_CD player                                 0.000     0.000     0.000
# em_Digital radio                             0.000     0.000     0.000
# em_Hands-free equipment                      1.000     1.000     0.000
# em_MP3                                       0.000     0.000     1.000
# em_On-board computer                         1.000     1.000     1.000
# em_Radio                                     1.000     1.000     0.000
# em_Sound system                              0.000     1.000     0.000
# em_Television                                0.000     0.000     0.000
# em_USB                                       0.000     0.000     0.000
# ex_Alloy wheels                              1.000     1.000     1.000
# ex_Cab or rented Car                         0.000     0.000     0.000
# ex_Catalytic Converter                       1.000     0.000     0.000
# ex_Handicapped enabled                       0.000     0.000     0.000
# ex_Right hand drive                          0.000     0.000     0.000
# ex_Roof rack                                 0.000     0.000     0.000
# ex_Shift paddles                             0.000     0.000     0.000
# ex_Ski bag                                   0.000     0.000     0.000
# ex_Sliding door                              0.000     0.000     0.000
# ex_Sport package                             0.000     0.000     0.000
# ex_Sport seats                               0.000     1.000     0.000
# ex_Sport suspension                          0.000     1.000     0.000
# ex_Touch screen                              0.000     0.000     0.000
# ex_Trailer hitch                             0.000     0.000     0.000
# ex_Tuned car                                 0.000     0.000     0.000
# ex_Voice Control                             1.000     1.000     1.000
# ex_Winter tyres                              0.000     0.000     0.000
# ss_ABS                                       1.000     1.000     1.000
# ss_Adaptive Cruise Control                   0.000     0.000     0.000
# ss_Adaptive headlights                       0.000     0.000     0.000
# ss_Alarm system                              0.000     0.000     0.000
# ss_Blind spot monitor                        0.000     0.000     0.000
# ss_Central door lock                         1.000     1.000     1.000
# ss_Central door lock with remote control     0.000     1.000     0.000
# ss_Daytime running lights                    1.000     1.000     1.000
# ss_Driver drowsiness detection               0.000     0.000     0.000
# ss_Driver-side airbag                        1.000     1.000     1.000
# ss_Electronic stability control              1.000     1.000     1.000
# ss_Emergency brake assistant                 0.000     0.000     0.000
# ss_Emergency system                          0.000     0.000     0.000
# ss_Fog lights                                1.000     0.000     0.000
# ss_Head airbag                               0.000     1.000     0.000
# ss_Immobilizer                               1.000     1.000     1.000
# ss_Isofix                                    1.000     1.000     1.000
# ss_LED Daytime Running Lights                0.000     0.000     0.000
# ss_LED Headlights                            0.000     0.000     0.000
# ss_Lane departure warning system             0.000     0.000     0.000
# ss_Night view assist                         0.000     0.000     0.000
# ss_Passenger-side airbag                     1.000     1.000     1.000
# ss_Power steering                            1.000     1.000     1.000
# ss_Rear airbag                               0.000     0.000     0.000
# ss_Side airbag                               1.000     1.000     1.000
# ss_Tire pressure monitoring system           1.000     1.000     1.000
# ss_Traction control                          1.000     1.000     1.000
# ss_Traffic sign recognition                  0.000     0.000     0.000
# ss_Xenon headlights                          1.000     1.000     0.000
# make_model_Audi A1                           1.000     1.000     1.000
# make_model_Audi A2                           0.000     0.000     0.000
# make_model_Audi A3                           0.000     0.000     0.000
# make_model_Opel Astra                        0.000     0.000     0.000
# make_model_Opel Corsa                        0.000     0.000     0.000
# make_model_Opel Insignia                     0.000     0.000     0.000
# make_model_Renault Clio                      0.000     0.000     0.000
# make_model_Renault Duster                    0.000     0.000     0.000
# make_model_Renault Espace                    0.000     0.000     0.000
# body_type_Compact                            0.000     0.000     0.000
# body_type_Convertible                        0.000     0.000     0.000
# body_type_Coupe                              0.000     0.000     0.000
# body_type_Off-Road                           0.000     0.000     0.000
# body_type_Sedans                             1.000     1.000     1.000
# body_type_Station wagon                      0.000     0.000     0.000
# body_type_Transporter                        0.000     0.000     0.000
# body_type_Van                                0.000     0.000     0.000
# vat_Price negotiable                         0.000     1.000     0.000
# vat_VAT deductible                           1.000     0.000     1.000
# type_Demonstration                           0.000     0.000     0.000
# type_Employee's car                          0.000     0.000     0.000
# type_New                                     0.000     0.000     0.000
# type_Pre-registered                          0.000     0.000     0.000
# type_Used                                    1.000     1.000     1.000
# fuel_Benzine                                 0.000     1.000     0.000
# fuel_Diesel                                  1.000     0.000     1.000
# fuel_Electric                                0.000     0.000     0.000
# fuel_LPG/CNG                                 0.000     0.000     0.000
# paint_type_Metallic                          1.000     1.000     1.000
# paint_type_Perl effect                       0.000     0.000     0.000
# paint_type_Uni/basic                         0.000     0.000     0.000
# upholstery_type_Cloth                        1.000     1.000     1.000
# upholstery_type_Part/Full Leather            0.000     0.000     0.000
# gear_type_Automatic                          1.000     1.000     1.000
# gear_type_Manual                             0.000     0.000     0.000
# gear_type_Semi-automatic                     0.000     0.000     0.000
# drive_chain_4WD                              0.000     0.000     0.000
# drive_chain_front                            1.000     1.000     1.000
# drive_chain_rear                             0.000     0.000     0.000
#
#                                                  3         4
# price                                    14500.000 16790.000
# km                                       73000.000 16200.000
# hp                                          66.000    66.000
# gears                                        6.000     7.000
# age                                          3.000     3.000
# previous_owners                              1.000     1.000
# inspection_new                               0.000     1.000
# displacement_cc                           1422.000  1422.000
# weight_kg                                 1195.000  1135.000
# cons_comb                                    3.800     4.100
# cc_Air conditioning                          0.000     1.000
# cc_Air suspension                            1.000     0.000
# cc_Armrest                                   1.000     1.000
# cc_Automatic climate control                 0.000     1.000
# cc_Auxiliary heating                         1.000     0.000
# cc_Cruise control                            0.000     0.000
# cc_Electric Starter                          0.000     0.000
# cc_Electric tailgate                         0.000     0.000
# cc_Electrical side mirrors                   1.000     1.000
# cc_Electrically adjustable seats             0.000     0.000
# cc_Electrically heated windshield            0.000     0.000
# cc_Heads-up display                          1.000     0.000
# cc_Heated steering wheel                     0.000     0.000
# cc_Hill Holder                               1.000     1.000
# cc_Keyless central door lock                 0.000     0.000
# cc_Leather seats                             0.000     0.000
# cc_Leather steering wheel                    1.000     1.000
# cc_Light sensor                              1.000     1.000
# cc_Lumbar support                            1.000     0.000
# cc_Massage seats                             0.000     0.000
# cc_Multi-function steering wheel             1.000     1.000
# cc_Navigation system                         1.000     0.000
# cc_Panorama roof                             0.000     0.000
# cc_Park Distance Control                     0.000     1.000
# cc_Parking assist system camera              0.000     0.000
# cc_Parking assist system self-steering       0.000     0.000
# cc_Parking assist system sensors front       0.000     0.000
# cc_Parking assist system sensors rear        0.000     1.000
# cc_Power windows                             1.000     1.000
# cc_Rain sensor                               1.000     1.000
# cc_Seat heating                              1.000     0.000
# cc_Seat ventilation                          0.000     0.000
# cc_Split rear seats                          1.000     0.000
# cc_Start-stop system                         1.000     1.000
# cc_Sunroof                                   0.000     0.000
# cc_Tinted windows                            0.000     0.000
# cc_Wind deflector                            0.000     0.000
# cc_Windshield                                0.000     0.000
# em_Bluetooth                                 1.000     1.000
# em_CD player                                 1.000     1.000
# em_Digital radio                             0.000     0.000
# em_Hands-free equipment                      1.000     1.000
# em_MP3                                       1.000     1.000
# em_On-board computer                         1.000     1.000
# em_Radio                                     1.000     1.000
# em_Sound system                              1.000     0.000
# em_Television                                0.000     0.000
# em_USB                                       1.000     1.000
# ex_Alloy wheels                              1.000     1.000
# ex_Cab or rented Car                         0.000     0.000
# ex_Catalytic Converter                       0.000     0.000
# ex_Handicapped enabled                       0.000     0.000
# ex_Right hand drive                          0.000     0.000
# ex_Roof rack                                 0.000     0.000
# ex_Shift paddles                             0.000     0.000
# ex_Ski bag                                   0.000     0.000
# ex_Sliding door                              0.000     0.000
# ex_Sport package                             0.000     1.000
# ex_Sport seats                               1.000     0.000
# ex_Sport suspension                          0.000     1.000
# ex_Touch screen                              0.000     0.000
# ex_Trailer hitch                             0.000     0.000
# ex_Tuned car                                 0.000     0.000
# ex_Voice Control                             1.000     1.000
# ex_Winter tyres                              0.000     0.000
# ss_ABS                                       1.000     1.000
# ss_Adaptive Cruise Control                   0.000     0.000
# ss_Adaptive headlights                       0.000     0.000
# ss_Alarm system                              1.000     0.000
# ss_Blind spot monitor                        0.000     0.000
# ss_Central door lock                         0.000     1.000
# ss_Central door lock with remote control     1.000     0.000
# ss_Daytime running lights                    0.000     0.000
# ss_Driver drowsiness detection               1.000     0.000
# ss_Driver-side airbag                        1.000     1.000
# ss_Electronic stability control              1.000     1.000
# ss_Emergency brake assistant                 0.000     0.000
# ss_Emergency system                          1.000     0.000
# ss_Fog lights                                0.000     1.000
# ss_Head airbag                               1.000     0.000
# ss_Immobilizer                               1.000     1.000
# ss_Isofix                                    1.000     1.000
# ss_LED Daytime Running Lights                0.000     0.000
# ss_LED Headlights                            0.000     0.000
# ss_Lane departure warning system             0.000     0.000
# ss_Night view assist                         0.000     0.000
# ss_Passenger-side airbag                     1.000     1.000
# ss_Power steering                            1.000     1.000
# ss_Rear airbag                               0.000     0.000
# ss_Side airbag                               1.000     1.000
# ss_Tire pressure monitoring system           1.000     1.000
# ss_Traction control                          0.000     1.000
# ss_Traffic sign recognition                  0.000     0.000
# ss_Xenon headlights                          0.000     1.000
# make_model_Audi A1                           1.000     1.000
# make_model_Audi A2                           0.000     0.000
# make_model_Audi A3                           0.000     0.000
# make_model_Opel Astra                        0.000     0.000
# make_model_Opel Corsa                        0.000     0.000
# make_model_Opel Insignia                     0.000     0.000
# make_model_Renault Clio                      0.000     0.000
# make_model_Renault Duster                    0.000     0.000
# make_model_Renault Espace                    0.000     0.000
# body_type_Compact                            0.000     0.000
# body_type_Convertible                        0.000     0.000
# body_type_Coupe                              0.000     0.000
# body_type_Off-Road                           0.000     0.000
# body_type_Sedans                             1.000     1.000
# body_type_Station wagon                      0.000     0.000
# body_type_Transporter                        0.000     0.000
# body_type_Van                                0.000     0.000
# vat_Price negotiable                         0.000     0.000
# vat_VAT deductible                           1.000     1.000
# type_Demonstration                           0.000     0.000
# type_Employee's car                          0.000     0.000
# type_New                                     0.000     0.000
# type_Pre-registered                          0.000     0.000
# type_Used                                    1.000     1.000
# fuel_Benzine                                 0.000     0.000
# fuel_Diesel                                  1.000     1.000
# fuel_Electric                                0.000     0.000
# fuel_LPG/CNG                                 0.000     0.000
# paint_type_Metallic                          1.000     1.000
# paint_type_Perl effect                       0.000     0.000
# paint_type_Uni/basic                         0.000     0.000
# upholstery_type_Cloth                        1.000     1.000
# upholstery_type_Part/Full Leather            0.000     0.000
# gear_type_Automatic                          1.000     1.000
# gear_type_Manual                             0.000     0.000
# gear_type_Semi-automatic                     0.000     0.000
# drive_chain_4WD                              0.000     0.000
# drive_chain_front                            1.000     1.000
# drive_chain_rear                             0.000     0.000

# %%
df_final.to_csv("final_scout_dummy.csv", index=False)

# %% [markdown]
# ***Data is ready for ML***
